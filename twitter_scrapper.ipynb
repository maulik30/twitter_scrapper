# %%
#Importing modules
from twitterscraper import query_tweets
import datetime as dt
import pandas as pd

# %%
#Setting begin and end dates for tweets
begin_date = dt.date(2020,3,1)
end_date = dt.date(2020,3,31)

# %%
#setting other arguments for query_tweets
limit=1000
lang= 'english'
user= 'realDonaldTrump'

# %%
#extracting tweets
tweets = query_tweets("corona", begindate=begin_date, enddate=end_date, limit=limit, lang=lang)
# Out:
# INFO: queries: ['corona since:2020-03-01 until:2020-03-02', 'corona since:2020-03-02 until:2020-03-04', 'corona since:2020-03-04 until:2020-03-05', 'corona since:2020-03-05 until:2020-03-07', 'corona since:2020-03-07 until:2020-03-08', 'corona since:2020-03-08 until:2020-03-10', 'corona since:2020-03-10 until:2020-03-11', 'corona since:2020-03-11 until:2020-03-13', 'corona since:2020-03-13 until:2020-03-14', 'corona since:2020-03-14 until:2020-03-16', 'corona since:2020-03-16 until:2020-03-17', 'corona since:2020-03-17 until:2020-03-19', 'corona since:2020-03-19 until:2020-03-20', 'corona since:2020-03-20 until:2020-03-22', 'corona since:2020-03-22 until:2020-03-23', 'corona since:2020-03-23 until:2020-03-25', 'corona since:2020-03-25 until:2020-03-26', 'corona since:2020-03-26 until:2020-03-28', 'corona since:2020-03-28 until:2020-03-29', 'corona since:2020-03-29 until:2020-03-31']
# INFO: Got 57 tweets (57 new).
# INFO: Got 112 tweets (55 new).
# INFO: Got 172 tweets (60 new).
# ...

# %%
#creating a dataframe from the tweets
df= pd.DataFrame(t.__dict__ for t in tweets)
df.head()
# Out:
#        screen_name            username              user_id  \
# 0  SilvioS43181112      Silvio Santana  1213119274404835333
# 1     LADYJAHRMANA              MCCALL             30687118
# 2  princessperfect        Princess🇱🇷🇯🇲  1009783303015104514
# 3   bIacksheepaway          kimdracula  1227192307704827904
# 4   TheyCallMePYT2  They Call Me P.Y.T   756238444863582212
#
#               tweet_id                                    tweet_url  \
# 0  1240790153062481920  /SilvioS43181112/status/1240790153062481920
# 1  1240790152932458496     /LADYJAHRMANA/status/1240790152932458496
# 2  1240790152722690052  /princessperfect/status/1240790152722690052
# 3  1240790152462700549   /bIacksheepaway/status/1240790152462700549
# 4  1240790152152100864   /TheyCallMePYT2/status/1240790152152100864
#
#             timestamp  timestamp_epochs  \
# 0 2020-03-19 23:59:59        1584662399
# 1 2020-03-19 23:59:59        1584662399
# 2 2020-03-19 23:59:59        1584662399
# ...
